# %%
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_core.prompts import ChatPromptTemplate
from langchain_chroma import Chroma


documents = DirectoryLoader(
    path="./knowledge_base/text_base/",
    glob="**/*.txt",
    loader_cls = TextLoader
)

splitter = RecursiveCharacterTextSplitter(
        chunk_size = 200,
        chunk_overlap=40
)

docs = documents.load_and_split(splitter)

print(len(docs))
print(docs[0].metadata)
#print(docs[0].metadata("source").split("/"))
# for doc in docs:
#     doc.metadata("filename") = doc.metadata("source").split("/")
# Out:
# 1486
# {'source': 'knowledge_base\\text_base\\it_support_network_and_connectivity_solutions.txt'}

# %%
docs[0].metadata['source'].split("\\")[-1].split(".")[0]
# Out:
# 'it_support_network_and_connectivity_solutions'
